# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

# Importando os dados -----------------------------------------------------
str_path = "./data-raw"

#filenames = glob.glob(os.path.join(str_path, "*.dbc"))

#db = pd.concat([read.dbc(filename) for filename in filenames], keys=tools.file_path_sans_ext(basename(filenames)))
db = pd.read_csv('hepatite_br.csv', encoding='ISO-8859-1').drop(columns='Unnamed: 0')

# Visualizando a estrutura dos dados --------------------------------------
print(db)
print(db.info())
print(db.describe())

# Organizando a base ------------------------------------------------------
tidy_db = db.copy()

tidy_db['EXPOSICAO'] = tidy_db.apply(
    lambda row: 1 if (row['SEXUAL'] == 1 or row['OUTRAS'] == 2) else (0 if (row['SEXUAL'] == 3 and row['OUTRAS'] == 3) else None),
    axis=1
)

tidy_db = tidy_db[['CS_SEXO', 'CS_RACA', 'CS_ESCOL_N', 'HEPATITE_N', 'HEPATITA', 'HEPATITB', 'HIV', 'OUTRA_DST', 'EXPOSICAO',
                   'ANTIHAVIGM','GEN_VHC', 'CLASSI_FIN', 'FORMA', 'CLAS_ETIOL']]

hepa_data = tidy_db[(tidy_db['HEPATITE_N'] == 2) & (tidy_db['CS_SEXO'] != "I") & (tidy_db['HEPATITA'] != 9) & 
                    (tidy_db['HEPATITB'] != 9) & (tidy_db['HIV'] != 9) & (tidy_db['OUTRA_DST'] != 9)].copy()

hepa_data = hepa_data[['CS_SEXO', 'HEPATITA', 'HEPATITB', 'HIV', 'OUTRA_DST', 'EXPOSICAO', 'ANTIHAVIGM', 'GEN_VHC', 'CLASSI_FIN']]

# Usando o encoder
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

hepa_data_copy = hepa_data.copy()
hepa_data_copy['CS_SEXO'] = label_encoder.fit_transform(hepa_data_copy['CS_SEXO'])

# Fill na
hepa_data_copy = hepa_data_copy.fillna(0)
# Dividindo o conjunto de dados em treinamento e teste
display(hepa_data_copy)
X = hepa_data_copy.drop(columns=['CLASSI_FIN'])
y = hepa_data_copy['CLASSI_FIN']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# randomForest ------------------------------------------------------------
# Criando modelo de classificação
rf_model = RandomForestClassifier(random_state=123)
rf_model.fit(X_train, y_train)

# Fazendo previsões no conjunto de testes
rf_predictions = rf_model.predict(X_test)

# Avaliando o desempenho do modelo
rf_confusion_matrix = confusion_matrix(y_test, rf_predictions)
rf_accuracy = accuracy_score(y_test, rf_predictions)
rf_precision = precision_score(y_test, rf_predictions, average='weighted')
rf_recall = recall_score(y_test, rf_predictions, average='weighted')

print("\nRandom Forest:")
print(rf_confusion_matrix)
print(f"Acurácia: {rf_accuracy}")
print(f"Precision: {rf_precision}")
print(f"Recall: {rf_recall}")

# ----------------------- OUTROS TESTES ------------------ #

# naiveBayes --------------------------------------------------------------
# Criando modelo de classificação Naïve Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Fazendo previsões no conjunto de testes
nb_predictions = nb_model.predict(X_test)

# Avaliando o desempenho do modelo
nb_confusion_matrix = confusion_matrix(y_test, nb_predictions)
nb_accuracy = accuracy_score(y_test, nb_predictions)
nb_precision = precision_score(y_test, nb_predictions, average='weighted')
nb_recall = recall_score(y_test, nb_predictions, average='weighted')

print("\nNaïve Bayes:")
print(nb_confusion_matrix)
print(f"Acurácia: {nb_accuracy}")
print(f"Precision: {nb_precision}")
print(f"Recall: {nb_recall}")


# nnet --------------------------------------------------------------------
# Criando modelo de rede neural
nn_model = MLPClassifier(hidden_layer_sizes=(10,), activation='logistic', max_iter=100, random_state=123)
nn_model.fit(X_train, y_train)


# Fazendo previsões no conjunto de testes
nn_predictions = nn_model.predict(X_test)

# Avaliando o desempenho do modelo
nn_confusion_matrix = confusion_matrix(y_test, nn_predictions)
nn_accuracy = accuracy_score(y_test, nn_predictions)
nn_precision = precision_score(y_test, nn_predictions, average='weighted')
nn_recall = recall_score(y_test, nn_predictions, average='weighted')

print("\nRede Neural:")
print(nn_confusion_matrix)
print(f"Acurácia: {nn_accuracy}")
print(f"Precision: {nn_precision}")
print(f"Recall: {nn_recall}")

# gradientBoosting --------------------------------------------------------
# Criando modelo Gradient Boosting
gb_model = GradientBoostingClassifier(random_state=123)
gb_model.fit(X_train, y_train)

# Fazendo previsões no conjunto de testes
gb_predictions = gb_model.predict(X_test)

# Avaliando o desempenho do modelo
gb_confusion_matrix = confusion_matrix(y_test, gb_predictions)
gb_accuracy = accuracy_score(y_test, gb_predictions)
gb_precision = precision_score(y_test, gb_predictions, average='weighted')
gb_recall = recall_score(y_test, gb_predictions, average='weighted')

print("\nGradient Boosting:")
print(gb_confusion_matrix)
print(f"Acurácia: {gb_accuracy}")
print(f"Precision: {gb_precision}")
print(f"Recall: {gb_recall}")
# Out:
# C:\Users\lnune\AppData\Local\Temp\ipykernel_9748\4197360136.py:15: DtypeWarning: Columns (15,19,24,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   db = pd.read_csv('hepatite_br.csv', encoding='ISO-8859-1').drop(columns='Unnamed: 0')
#         TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0            2       B19  2007-01-02   200701    2007       11.0      110140
# 1            2       B19  2007-01-22   200704    2007       11.0      110030
# 2            2       B19  2007-01-01   200701    2007       11.0      110030
# 3            2       B19  2007-01-05   200701    2007       11.0      110004
# 4            2       B19  2007-01-09   200702    2007       11.0      110045
# ...        ...       ...         ...      ...     ...        ...         ...
# 594230       2       B19  2020-12-24   202052    2020       53.0      530010
# 594231       2       B19  2020-12-28   202053    2020       53.0      530010
# 594232       2       B19  2020-12-28   202053    2020       53.0      530010
# 594233       2       B19  2020-12-29   202053    2020       53.0      530010
# 594234       2       B19  2020-12-30   202053    2020       53.0      530010
#
#         ID_REGIONA  DT_SIN_PRI  SEM_PRI  ...  ANTIHDV TP_SOROHCV  GEN_VHC  \
# 0           1481.0  2007-01-01   200701  ...      2.0        4.0      7.0
# 1           1479.0  2006-12-20   200651  ...      2.0        4.0      7.0
# 2           1479.0  2006-11-07   200645  ...      4.0        4.0      NaN
# 3           1480.0  2006-12-20   200651  ...      4.0        4.0      7.0
# 4           1481.0  2007-01-09   200702  ...      4.0        1.0      9.0
# ...            ...         ...      ...  ...      ...        ...      ...
# 594230         NaN  2020-12-24   202052  ...      4.0        4.0      7.0
# 594231         NaN  2020-12-19   202051  ...      4.0        1.0      NaN
# 594232         NaN  2020-12-21   202052  ...      4.0        1.0      9.0
# 594233         NaN  2020-12-23   202052  ...      2.0        2.0      7.0
# 594234         NaN  2020-07-30   202031  ...      4.0        4.0      7.0
#
#         COLETAMARC CLASSI_FIN  FORMA  CLAS_ETIOL  FONTE  DT_ENCERRA  DSFONTE
# 0              NaN        1.0    4.0         2.0   99.0  2007-04-09      NaN
# 1       2006-12-20        1.0    2.0         2.0   99.0  2007-04-16      NaN
# 2              NaN        2.0    1.0         1.0   11.0  2007-01-23      NaN
# 3       2006-12-20        1.0    2.0         2.0    1.0  2007-08-30      NaN
# 4       2006-12-01        1.0    2.0         3.0   99.0  2007-03-06      NaN
# ...            ...        ...    ...         ...    ...         ...      ...
# 594230  2020-12-24        1.0    4.0         2.0    NaN  2021-01-20      NaN
# 594231  2021-01-07        1.0    2.0         3.0   99.0  2020-12-28      NaN
# 594232  2020-12-21        1.0    2.0         3.0   99.0  2020-12-28      NaN
# 594233  2020-12-23        1.0    2.0         2.0   99.0  2020-12-29      NaN
# 594234  2020-07-30        1.0    4.0         2.0   99.0  2020-12-30      NaN
#
# [594235 rows x 79 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594235 entries, 0 to 594234
# Data columns (total 79 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   TP_NOT      594235 non-null  int64
#  1   ID_AGRAVO   594235 non-null  object
#  2   DT_NOTIFIC  594235 non-null  object
#  3   SEM_NOT     594235 non-null  int64
#  4   NU_ANO      594235 non-null  int64
#  5   SG_UF_NOT   594234 non-null  float64
#  6   ID_MUNICIP  594235 non-null  int64
#  7   ID_REGIONA  532194 non-null  float64
#  8   DT_SIN_PRI  594235 non-null  object
#  9   SEM_PRI     594235 non-null  int64
#  10  NU_IDADE_N  594235 non-null  int64
#  11  CS_SEXO     594235 non-null  object
#  12  CS_GESTANT  594217 non-null  float64
#  13  CS_RACA     580513 non-null  float64
#  14  CS_ESCOL_N  553950 non-null  object
#  15  SG_UF       594115 non-null  float64
#  16  ID_MN_RESI  594115 non-null  float64
#  17  ID_RG_RESI  0 non-null       float64
#  18  ID_PAIS     594234 non-null  object
#  19  DT_DIGITA   0 non-null       float64
#  20  DT_TRASSE   0 non-null       float64
#  21  MIGRADO_W   0 non-null       float64
#  22  DT_INVEST   592874 non-null  object
#  23  ID_OCUPA_N  320543 non-null  object
#  24  HEPATITE_N  594223 non-null  float64
#  25  HEPATITA    594217 non-null  float64
#  26  HEPATITB    594217 non-null  float64
#  27  INSTITUCIO  594206 non-null  float64
#  28  HIV         594219 non-null  float64
#  29  OUTRA_DST   594218 non-null  float64
#  30  SEXUAL      594212 non-null  float64
#  31  DOMICILI    594211 non-null  float64
#  32  OCUPACIO    594207 non-null  float64
#  33  MEDICAMENT  594204 non-null  float64
#  34  TATU_PIER   594202 non-null  float64
#  35  MATBIOLOGI  594203 non-null  float64
#  36  INAL_CRACK  594200 non-null  float64
#  37  ACUPUNTURA  594203 non-null  float64
#  38  TRANSFUSAO  594203 non-null  float64
#  39  INJETAVEIS  594201 non-null  float64
#  40  CIRURGICO   594202 non-null  float64
#  41  AGUA_ALIME  594202 non-null  float64
#  42  DENTARIO    594200 non-null  float64
#  43  TRESMAIS    594202 non-null  float64
#  44  HEMODIALIS  594186 non-null  float64
#  45  TRANSPLA    594201 non-null  float64
#  46  OUTRAS      594201 non-null  float64
#  47  DT_ACIDENT  60083 non-null   object
#  48  CO_UF_EXP   39404 non-null   object
#  49  CO_MUN_EXP  37177 non-null   float64
#  50  CO_UF_EX2   2683 non-null    float64
#  51  CO_MUN_EX2  2575 non-null    float64
#  52  CO_UF_EX3   591 non-null     float64
#  53  CO_MUN_EX3  562 non-null     float64
#  54  BANCOSANGU  444379 non-null  float64
#  55  RES_HBSAG   82413 non-null   float64
#  56  RE_ANTIHBC  81857 non-null   float64
#  57  RE_ANTIHCV  82765 non-null   float64
#  58  DT_COLETA   70049 non-null   object
#  59  ANTIHAVIGM  594142 non-null  float64
#  60  ANTIHBS     594187 non-null  float64
#  61  ANTIHDVIGM  594133 non-null  float64
#  62  AGHBS       594215 non-null  float64
#  63  AGHBE       594151 non-null  float64
#  64  ANTIHEVIGM  594135 non-null  float64
#  65  ANTIHBCIGM  594149 non-null  float64
#  66  ANTIHBE     594151 non-null  float64
#  67  ANTIHCV     594216 non-null  float64
#  68  HBC_TOTAL   594193 non-null  float64
#  69  ANTIHDV     594134 non-null  float64
#  70  TP_SOROHCV  594162 non-null  float64
#  71  GEN_VHC     474855 non-null  float64
#  72  COLETAMARC  508498 non-null  object
#  73  CLASSI_FIN  592086 non-null  float64
#  74  FORMA       496919 non-null  float64
#  75  CLAS_ETIOL  528731 non-null  float64
#  76  FONTE       516412 non-null  float64
#  77  DT_ENCERRA  591707 non-null  object
#  78  DSFONTE     11976 non-null   object
# dtypes: float64(59), int64(6), object(14)
# memory usage: 358.2+ MB
# None
#          TP_NOT        SEM_NOT         NU_ANO      SG_UF_NOT     ID_MUNICIP  \
# count  594235.0  594235.000000  594235.000000  594234.000000  594235.000000
# mean        2.0  200715.575829    2013.178349      34.174317  343632.143694
# std         0.0   11203.964286       3.825538       9.718699   97412.499083
# min         2.0       1.000000    2007.000000      11.000000  110001.000000
# 25%         2.0  201019.000000    2010.000000      31.000000  312770.000000
# 50%         2.0  201333.000000    2013.000000      35.000000  354890.000000
# 75%         2.0  201647.000000    2016.000000      42.000000  420300.000000
# max         2.0  202053.000000    2020.000000      53.000000  530010.000000
#
#           ID_REGIONA        SEM_PRI     NU_IDADE_N     CS_GESTANT  \
# count  532194.000000  594235.000000  594235.000000  594217.000000
# mean     1593.766420  200631.904348    4028.870590       5.659390
# std       714.961103   11188.739761     152.372558       1.121193
# min      1331.000000       1.000000       3.000000       1.000000
# 25%      1345.000000  200928.000000    4029.000000       5.000000
# 50%      1449.000000  201248.000000    4043.000000       6.000000
# 75%      1584.000000  201620.000000    4054.000000       6.000000
# max      6256.000000  202053.000000    4127.000000       9.000000
#
#              CS_RACA  ...        ANTIHBE        ANTIHCV      HBC_TOTAL  \
# count  580513.000000  ...  594151.000000  594216.000000  594193.000000
# mean        2.854284  ...       3.414694       1.911709       2.642874
# std         2.415578  ...       1.092593       1.189385       1.304507
# min         1.000000  ...       1.000000       1.000000       1.000000
# 25%         1.000000  ...       4.000000       1.000000       1.000000
# 50%         2.000000  ...       4.000000       1.000000       2.000000
# 75%         4.000000  ...       4.000000       2.000000       4.000000
# max         9.000000  ...       4.000000       4.000000       4.000000
#
#              ANTIHDV     TP_SOROHCV        GEN_VHC     CLASSI_FIN  \
# count  594134.000000  594162.000000  474855.000000  592086.000000
# mean        3.864209       2.949132       6.162003       1.778238
# std         0.516768       1.364001       2.583797       1.994823
# min         1.000000       1.000000       1.000000       1.000000
# 25%         4.000000       1.000000       7.000000       1.000000
# 50%         4.000000       4.000000       7.000000       1.000000
# 75%         4.000000       4.000000       7.000000       1.000000
# max         4.000000       9.000000       9.000000       8.000000
#
#                FORMA     CLAS_ETIOL          FONTE
# count  496919.000000  528731.000000  516412.000000
# mean        1.899181       2.925800      52.527995
# std         0.642793       6.747756      46.922179
# min         1.000000       1.000000       1.000000
# 25%         2.000000       2.000000       3.000000
# 50%         2.000000       3.000000      99.000000
# 75%         2.000000       3.000000      99.000000
# max         8.000000      99.000000      99.000000
#
# [8 rows x 65 columns]
#         CS_SEXO  HEPATITA  HEPATITB  HIV  OUTRA_DST  EXPOSICAO  ANTIHAVIGM  \
# 0             0       3.0       3.0  2.0        2.0        0.0         4.0
# 1             0       3.0       2.0  2.0        2.0        0.0         4.0
# 3             0       3.0       1.0  2.0        1.0        0.0         4.0
# 4             0       3.0       1.0  2.0        2.0        0.0         4.0
# 5             0       3.0       1.0  2.0        2.0        0.0         4.0
# ...         ...       ...       ...  ...        ...        ...         ...
# 594223        0       1.0       1.0  2.0        2.0        0.0         4.0
# 594224        1       3.0       2.0  2.0        2.0        0.0         4.0
# 594225        0       3.0       1.0  2.0        2.0        1.0         2.0
# 594226        0       1.0       1.0  2.0        2.0        0.0         4.0
# 594227        1       3.0       3.0  2.0        2.0        0.0         4.0
#
#         GEN_VHC  CLASSI_FIN
# 0           7.0         1.0
# 1           7.0         1.0
# 3           7.0         1.0
# 4           9.0         1.0
# 5           7.0         4.0
# ...         ...         ...
# 594223      7.0         1.0
# 594224      0.0         1.0
# 594225      1.0         1.0
# 594226      7.0         1.0
# 594227      1.0         1.0
#
# [275565 rows x 9 columns]
# c:\Users\lnune\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\lnune\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest:
# [[    0   111     0     0     0     0]
#  [    0 46462     0     2    23    28]
#  [    0   155     0     0     0     0]
#  [    0   930     0     0     1     0]
#  [    0  3237     0     0    23     1]
#  [    0  4135     0     1     2     2]]
# Acurácia: 0.8434852031281186
# Precision: 0.7452058368099114
# Recall: 0.8434852031281186
#
# Naïve Bayes:
# [[    0   109     0     0     0     2]
#  [    1 44492    18     0   629  1375]
#  [    0   151     0     0     2     2]
#  [    0   900     0     0     6    25]
#  [    0  3073     1     0    53   134]
#  [    0  3837     0     0    51   252]]
# Acurácia: 0.8128209315406528
# Precision: 0.7292198714812633
# Recall: 0.8128209315406528
# c:\Users\lnune\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Rede Neural:
# [[    0   111     0     0     0     0]
#  [    0 46515     0     0     0     0]
#  [    0   155     0     0     0     0]
#  [    0   931     0     0     0     0]
#  [    0  3261     0     0     0     0]
#  [    0  4140     0     0     0     0]]
# Acurácia: 0.8439932502313429
# Precision: 0.7123246064360661
# Recall: 0.8439932502313429
#
# Gradient Boosting:
# [[    0   111     0     0     0     0]
#  [    1 46500     0     0    14     0]
#  [    0   155     0     0     0     0]
#  [    0   930     0     0     1     0]
#  [    0  3240     0     0    21     0]
#  [    0  4138     0     0     2     0]]
# Acurácia: 0.8441021174677481
# Precision: 0.745298007401944
# Recall: 0.8441021174677481
# c:\Users\lnune\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
